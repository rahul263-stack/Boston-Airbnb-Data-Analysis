# %% [markdown]
# ### BUSINESS UNDERSTANDING
# The airbnb dataset of boston contains data about AirBnB listings in the Boston city. this data set includes calendar listing and reviewss of all the listings by users. I am going to answer the following questions using this data set.

# %%
#import
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import spacy
import afinn 
from afinn import Afinn
from math import floor

import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the data from  the provided Airbnb boston data set
calendar = pd.read_csv('data/calendar.csv')
listings = pd.read_csv('data/listings.csv')
reviews = pd.read_csv('data/reviews.csv')

# %%
#listing top five
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
#listing shapr
listings.shape
# Out:
# (3585, 95)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
# id                                  3585 non-null int64
# listing_url                         3585 non-null object
# scrape_id                           3585 non-null int64
# last_scraped                        3585 non-null object
# name                                3585 non-null object
# summary                             3442 non-null object
# space                               2528 non-null object
# description                         3585 non-null object
# experiences_offered                 3585 non-null object
# neighborhood_overview               2170 non-null object
# notes                               1610 non-null object
# transit                             2295 non-null object
# access                              2096 non-null object
# interaction                         2031 non-null object
# house_rules                         2393 non-null object
# thumbnail_url                       2986 non-null object
# medium_url                          2986 non-null object
# picture_url                         3585 non-null object
# xl_picture_url                      2986 non-null object
# host_id                             3585 non-null int64
# host_url                            3585 non-null object
# host_name                           3585 non-null object
# host_since                          3585 non-null object
# host_location                       3574 non-null object
# host_about                          2276 non-null object
# host_response_time                  3114 non-null object
# host_response_rate                  3114 non-null object
# host_acceptance_rate                3114 non-null object
# host_is_superhost                   3585 non-null object
# host_thumbnail_url                  3585 non-null object
# host_picture_url                    3585 non-null object
# host_neighbourhood                  3246 non-null object
# host_listings_count                 3585 non-null int64
# host_total_listings_count           3585 non-null int64
# host_verifications                  3585 non-null object
# host_has_profile_pic                3585 non-null object
# host_identity_verified              3585 non-null object
# street                              3585 non-null object
# neighbourhood                       3042 non-null object
# neighbourhood_cleansed              3585 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# city                                3583 non-null object
# state                               3585 non-null object
# zipcode                             3547 non-null object
# market                              3571 non-null object
# smart_location                      3585 non-null object
# country_code                        3585 non-null object
# country                             3585 non-null object
# latitude                            3585 non-null float64
# longitude                           3585 non-null float64
# is_location_exact                   3585 non-null object
# property_type                       3582 non-null object
# room_type                           3585 non-null object
# accommodates                        3585 non-null int64
# bathrooms                           3571 non-null float64
# bedrooms                            3575 non-null float64
# beds                                3576 non-null float64
# bed_type                            3585 non-null object
# amenities                           3585 non-null object
# square_feet                         56 non-null float64
# price                               3585 non-null object
# weekly_price                        892 non-null object
# monthly_price                       888 non-null object
# security_deposit                    1342 non-null object
# cleaning_fee                        2478 non-null object
# guests_included                     3585 non-null int64
# extra_people                        3585 non-null object
# minimum_nights                      3585 non-null int64
# maximum_nights                      3585 non-null int64
# calendar_updated                    3585 non-null object
# has_availability                    0 non-null float64
# availability_30                     3585 non-null int64
# availability_60                     3585 non-null int64
# availability_90                     3585 non-null int64
# availability_365                    3585 non-null int64
# calendar_last_scraped               3585 non-null object
# number_of_reviews                   3585 non-null int64
# first_review                        2829 non-null object
# last_review                         2829 non-null object
# review_scores_rating                2772 non-null float64
# review_scores_accuracy              2762 non-null float64
# review_scores_cleanliness           2767 non-null float64
# review_scores_checkin               2765 non-null float64
# review_scores_communication         2767 non-null float64
# review_scores_location              2763 non-null float64
# review_scores_value                 2764 non-null float64
# requires_license                    3585 non-null object
# license                             0 non-null float64
# jurisdiction_names                  0 non-null float64
# instant_bookable                    3585 non-null object
# cancellation_policy                 3585 non-null object
# require_guest_profile_picture       3585 non-null object
# require_guest_phone_verification    3585 non-null object
# calculated_host_listings_count      3585 non-null int64
# reviews_per_month                   2829 non-null float64
# dtypes: float64(18), int64(15), object(62)
# memory usage: 2.6+ MB

# %%
#calander top five
calendar.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
#calendar shape
calendar.shape
# Out:
# (1308890, 4)

# %%
#calendar shape
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308890 entries, 0 to 1308889
# Data columns (total 4 columns):
# listing_id    1308890 non-null int64
# date          1308890 non-null object
# available     1308890 non-null object
# price         643037 non-null object
# dtypes: int64(1), object(3)
# memory usage: 39.9+ MB

# %%
#reviews top five
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
reviews.shape
# Out:
# (68275, 6)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 6 columns):
# listing_id       68275 non-null int64
# id               68275 non-null int64
# date             68275 non-null object
# reviewer_id      68275 non-null int64
# reviewer_name    68275 non-null object
# comments         68222 non-null object
# dtypes: int64(3), object(3)
# memory usage: 3.1+ MB

# %%
#Exploring - experiences_offered
print('Value counts for experiences_offered: ', listings['experiences_offered'].value_counts())
# Out:
# Value counts for experiences_offered:  none    3585
# Name: experiences_offered, dtype: int64

# %%
#Exploring - host_unction
print('Value counts for host_location: ', listings['host_location'].value_counts())
# Out:
# Value counts for host_location:  Boston, Massachusetts, United States               2421
# US                                                  521
# New York, New York, United States                   113
# Montreal, Quebec, Canada                             59
# Middlesex County, Massachusetts, United States       50
# Cambridge, Massachusetts, United States              42
# Massachusetts, United States                         28
# Spokane, Washington, United States                   25
# Brookline, Massachusetts, United States              19
# Somerville, Massachusetts, United States             17
# Milton, Massachusetts, United States                 10
# Medford, Massachusetts, United States                10
# San Francisco, California, United States              7
# Santa Monica, California, United States               6
# Newton, Massachusetts, United States                  6
# United States                                         6
# Cohasset, Massachusetts, United States                6
# Waltham, Massachusetts, United States                 5
# Washington, District of Columbia, United States       5
# Miami, Florida, United States                         5
# Belmont, Massachusetts, United States                 5
# Paris, Île-de-France, France                          5
# Jersey City, New Jersey, United States                5
# Quincy, Massachusetts, United States                  4
# Atlanta, Georgia, United States                       4
# York, Maine, United States                            3
# Gearhart, Oregon, United States                       3
# Los Angeles, California, United States                3
# Lexington, Massachusetts, United States               3
# Easton, Massachusetts, United States                  3
#                                                    ...
# Temecula, California, United States                   1
# Weymouth, Massachusetts, United States                1
# Cape Coral, Florida, United States                    1
# Mumbai, Maharashtra, India                            1
# Reno, Nevada, United States                           1
# Knoxville, Tennessee, United States                   1
# Vienna, Virginia, United States                       1
# USA                                                   1
# Braintree, Massachusetts, United States               1
# CA                                                    1
# Chongqing, Chongqing, China                           1
# Toronto, Ontario, Canada                              1
# Providence, Rhode Island, United States               1
# Randolph, Massachusetts, United States                1
# Santos, State of São Paulo, Brazil                    1
# Norwich, Vermont, United States                       1
# Marblehead, Massachusetts, United States              1
# San Diego, California, United States                  1
# Hillside, New Jersey, United States                   1
# Newburyport, Massachusetts, United States             1
# Berlin, Massachusetts, United States                  1
# San Isidro, Buenos Aires Province, Argentina          1
# Acton, Massachusetts, United States                   1
# Redwood City, California, United States               1
# Lynnfield, Massachusetts, United States               1
# Beijing, Beijing, China                               1
# IT                                                    1
# Hillsboro Beach, Florida, United States               1
# Bogota, Bogota, Colombia                              1
# Quito, Pichincha, Ecuador                             1
# Name: host_location, Length: 176, dtype: int64

# %%
#exploring - review_value

print('Value counts for reviews_score: ', listings['review_scores_value'].value_counts())
# Out:
# Value counts for reviews_score:  10.0    1177
# 9.0     1130
# 8.0      334
# 7.0       51
# 6.0       49
# 4.0       12
# 2.0        7
# 5.0        2
# 3.0        2
# Name: review_scores_value, dtype: int64

# %%
#plotting visualisation of the review_score
revi_vals = listings['review_scores_value'].value_counts()
(revi_vals/listings.shape[0]).plot(kind="bar", color=['powderblue', 'peachpuff', 'lightcoral'])
plt.title("Property Type");

# %% [markdown]
# <H6>ANALYSIS<H6>
#     From the above graph we can determine that maximum number of the properties are very good as per the reviews provieded by the users

# %%
#property type and plotting visualisation
prop_vals = listings['property_type'].value_counts()
(prop_vals/listings.shape[0]).plot(kind="bar", color=['powderblue', 'peachpuff', 'lightcoral'])
plt.title("Property Type");

# %% [markdown]
# <H6>Analysis<H6>
#     From the above bar graph we can see that in boston maximum number of properties are Apartment follower by house and condominium

# %%
# explorinf - host_response_time and plotting visualisation
host_response_vals = listings['host_response_time'].value_counts()
(host_response_vals/listings.shape[0]).plot(kind="bar", color=['powderblue', 'peachpuff', 'lightcoral']);
plt.title("Host Response Times");

# %% [markdown]
# <H6>ANALYSIS<H6>
#     The hosts response time is quite recommendable as per our analysis

# %%
#catergotising listing data in diifernt parts 
data_level=['property_type','room_type','bed_type','cancellation_policy']
[listings[c].value_counts() for c in data_level]
# Out:
# [Apartment          2612
#  House               562
#  Condominium         231
#  Townhouse            54
#  Bed & Breakfast      41
#  Loft                 39
#  Other                17
#  Boat                 12
#  Villa                 6
#  Entire Floor          4
#  Dorm                  2
#  Camper/RV             1
#  Guesthouse            1
#  Name: property_type, dtype: int64,
#  Entire home/apt    2127
#  Private room       1378
#  Shared room          80
#  Name: room_type, dtype: int64,
#  Real Bed         3453
#  Futon              51
#  Airbed             40
#  Pull-out Sofa      31
#  Couch              10
#  Name: bed_type, dtype: int64,
#  strict             1582
#  flexible            999
#  moderate            919
#  super_strict_30      85
#  Name: cancellation_policy, dtype: int64]

# %% [markdown]
# ### Observations
#     1. Entire room is he most popular type room_type.
#     2. Each property has an average of 1.4 bedrooms
#     3. There are total of 56 neighbourhood in boston.

# %%
#Showing columns with missing values
def show_missing_vals(df):
    """Description: This process is for listing  the missing values
     Arguments:
            vals: values"""
    missing_values = df.isnull().sum().sort_values(ascending = False)
    
    return missing_values.iloc[missing_values.nonzero()[0]]
show_missing_vals(listings)
# Out:
# C:\Users\Rahul\Miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   """
# neighbourhood_group_cleansed    3585
# jurisdiction_names              3585
# license                         3585
# has_availability                3585
# square_feet                     3529
# monthly_price                   2697
# weekly_price                    2693
# security_deposit                2243
# notes                           1975
# interaction                     1554
# access                          1489
# neighborhood_overview           1415
# host_about                      1309
# transit                         1290
# house_rules                     1192
# cleaning_fee                    1107
# space                           1057
# review_scores_accuracy           823
# review_scores_location           822
# review_scores_value              821
# review_scores_checkin            820
# review_scores_cleanliness        818
# review_scores_communication      818
# review_scores_rating             813
# reviews_per_month                756
# first_review                     756
# last_review                      756
# thumbnail_url                    599
# medium_url                       599
# xl_picture_url                   599
# neighbourhood                    543
# host_response_time               471
# host_acceptance_rate             471
# host_response_rate               471
# host_neighbourhood               339
# summary                          143
# zipcode                           38
# market                            14
# bathrooms                         14
# host_location                     11
# bedrooms                          10
# beds                               9
# property_type                      3
# city                               2
# dtype: int64

# %%
#Function for handling missing values
def handle_missing_remove(df):
    """handle_missing_remove funvtion is nasically definef for handelling the issing values obtained in the 
    previous column"""
    temp_df=df.copy()
    #Fill 0 in place of missing records for number of bedrooms,bathrooms,beds
    """There are a lot of fields which have only one level and not useful for analysis. Instead of dropping these fields,
    only a subset of fields is considered for calculating optimal price."""
    temp_df.beds.fillna(0,inplace=True)
    temp_df.bedrooms.fillna(0,inplace=True)
    temp_df.bathrooms.fillna(0,inplace=True)
    
    #Remove columns license and squarefeet which have more than 95% missing values
    temp_df.drop(['license','square_feet'],axis=1,inplace=True)
     
    return temp_df

# %%
listings = handle_missing_remove(listings)
show_missing_values(listings)
# Out:
# C:\Users\Rahul\Miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   """
# neighbourhood_group_cleansed    3585
# jurisdiction_names              3585
# has_availability                3585
# monthly_price                   2697
# weekly_price                    2693
# security_deposit                2243
# notes                           1975
# interaction                     1554
# access                          1489
# neighborhood_overview           1415
# host_about                      1309
# transit                         1290
# house_rules                     1192
# cleaning_fee                    1107
# space                           1057
# review_scores_accuracy           823
# review_scores_location           822
# review_scores_value              821
# review_scores_checkin            820
# review_scores_cleanliness        818
# review_scores_communication      818
# review_scores_rating             813
# first_review                     756
# last_review                      756
# reviews_per_month                756
# thumbnail_url                    599
# xl_picture_url                   599
# medium_url                       599
# neighbourhood                    543
# host_response_time               471
# host_response_rate               471
# host_acceptance_rate             471
# host_neighbourhood               339
# summary                          143
# zipcode                           38
# market                            14
# host_location                     11
# property_type                      3
# city                               2
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
#function to preprocess features
def preprocess(df):
    
    temp_df = df.copy()
    temp_df = temp_df.replace(
            {
            'host_has_profile_pic': {'t': True, 'f': False},
            'host_identity_verified': {'t': True, 'f': False},
            'instant_bookable': {'t': True, 'f': False},
            }
    )
        
    ## Recode property_type
    def recode_prop(value):
        if value not in ['House', 'Apartment','Condominium','Townhouse','Loft']:
            return 'other_prop_type'
        return value

    temp_df['property_type'] = temp_df['property_type'].apply(recode_prop)

    ## Recode bed_type
    def recode_bed(value):
        if value not in ['Real Bed']:
            return 'other_bed_type'
        return value

    temp_df['bed_type'] = temp_df['bed_type'].apply(recode_bed)
        
    #Calculate the bedroom and bathroom share per person. Higher the share, more the comfort.
    temp_df = temp_df.assign(
        bedroom_share = temp_df.bedrooms/temp_df.accommodates,
        bathroom_share = temp_df.bathrooms/temp_df.accommodates,
        
    )
    
    df=temp_df
    print("Pre-processing completed...")
    return df
listings=preprocess(listings)
# Out:
# Pre-processing completed...

# %%
#creating dummy columns by one hot encoding
def create_dummies(df, columns = ['room_type', 'property_type', 'bed_type', 'cancellation_policy']):
    for column in columns:
        dummies = pd.get_dummies(df[column], prefix = column)
        df = pd.concat([df,dummies], axis = 1)
    return df
listings = create_dummies(listings)

# %% [markdown]
# ## Preprocess amenities

# %%
# Blank missing values
listings.loc[listings['amenities']=='{}','amenities']=""

# %%
#Removing the symbols and split the amenities with | as separator
listings['amenities'] = listings['amenities'].map(
    lambda amns: "|".join([amn.replace("}", "").replace("{", "").replace('"', "")\
                           for amn in amns.split(",")]))
listings['amenities'].head()
# Out:
# 0    TV|Wireless Internet|Kitchen|Free Parking on P...
# 1    TV|Internet|Wireless Internet|Air Conditioning...
# 2    TV|Cable TV|Wireless Internet|Air Conditioning...
# 3    TV|Internet|Wireless Internet|Air Conditioning...
# 4    Internet|Wireless Internet|Air Conditioning|Ki...
# Name: amenities, dtype: object

# %%
#Take the unique list of amenities across all listings
amenities = np.unique(np.concatenate(listings['amenities'].map(lambda amns: amns.split("|")).values))
amenities
# Out:
# array(['', '24-Hour Check-in', 'Air Conditioning', 'Breakfast',
#        'Buzzer/Wireless Intercom', 'Cable TV', 'Carbon Monoxide Detector',
#        'Cat(s)', 'Dog(s)', 'Doorman', 'Dryer', 'Elevator in Building',
#        'Essentials', 'Family/Kid Friendly', 'Fire Extinguisher',
#        'First Aid Kit', 'Free Parking on Premises',
#        'Free Parking on Street', 'Gym', 'Hair Dryer', 'Hangers',
#        'Heating', 'Hot Tub', 'Indoor Fireplace', 'Internet', 'Iron',
#        'Kitchen', 'Laptop Friendly Workspace', 'Lock on Bedroom Door',
#        'Other pet(s)', 'Paid Parking Off Premises', 'Pets Allowed',
#        'Pets live on this property', 'Pool', 'Safety Card', 'Shampoo',
#        'Smoke Detector', 'Smoking Allowed', 'Suitable for Events', 'TV',
#        'Washer', 'Washer / Dryer', 'Wheelchair Accessible',
#        'Wireless Internet', 'translation missing: en.hosting_amenity_49',
#        'translation missing: en.hosting_amenity_50'], dtype='<U42')

# %%
#Map the presence or absence of amenities for each listing
amenities_matrix = np.array([listings['amenities'].map(lambda amns: amn in amns).values for amn in amenities])
amenities_matrix
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [False, False, False, ..., False, False, False],
#        [False,  True,  True, ..., False, False, False],
#        ...,
#        [ True,  True,  True, ..., False, False,  True],
#        [False, False,  True, ...,  True, False,  True],
#        [False, False,  True, ...,  True,  True,  True]])

# %%
amen=pd.DataFrame(data=amenities_matrix.T, columns=amenities)
amen.head()
# Out:
#          24-Hour Check-in  Air Conditioning  Breakfast  \
# 0  True             False             False      False
# 1  True             False              True      False
# 2  True             False              True      False
# 3  True             False              True       True
# 4  True             False              True       True
#
#    Buzzer/Wireless Intercom  Cable TV  Carbon Monoxide Detector  Cat(s)  \
# 0                     False     False                     False   False
# 1                     False     False                      True   False
# 2                     False      True                      True   False
# 3                     False     False                      True   False
# 4                     False     False                      True   False
#
#    Dog(s)  Doorman  ...  Smoke Detector  Smoking Allowed  Suitable for Events  \
# 0    True    False  ...            True            False                False
# 1    True    False  ...            True            False                False
# 2   False    False  ...            True            False                False
# 3   False    False  ...            True            False                False
# 4   False    False  ...            True            False                False
#
#       TV  Washer  Washer / Dryer  Wheelchair Accessible  Wireless Internet  \
# 0   True    True           False                  False               True
# 1   True    True           False                  False               True
# 2   True    True           False                  False               True
# 3   True    True           False                  False               True
# 4  False   False           False                  False               True
#
#    translation missing: en.hosting_amenity_49  \
# 0                                       False
# 1                                       False
# 2                                        True
# 3                                       False
# 4                                       False
#
#    translation missing: en.hosting_amenity_50
# 0                                       False
# 1                                       False
# 2                                        True
# 3                                       False
# 4                                       False
#
# [5 rows x 46 columns]

# %%
#Concat the listing id to amen dataframe
listings_amenities = pd.concat([amen,listings['id']], axis=1)
listings_amenities.head()
# Out:
#          24-Hour Check-in  Air Conditioning  Breakfast  \
# 0  True             False             False      False
# 1  True             False              True      False
# 2  True             False              True      False
# 3  True             False              True       True
# 4  True             False              True       True
#
#    Buzzer/Wireless Intercom  Cable TV  Carbon Monoxide Detector  Cat(s)  \
# 0                     False     False                     False   False
# 1                     False     False                      True   False
# 2                     False      True                      True   False
# 3                     False     False                      True   False
# 4                     False     False                      True   False
#
#    Dog(s)  Doorman  ...  Smoking Allowed  Suitable for Events     TV  Washer  \
# 0    True    False  ...            False                False   True    True
# 1    True    False  ...            False                False   True    True
# 2   False    False  ...            False                False   True    True
# 3   False    False  ...            False                False   True    True
# 4   False    False  ...            False                False  False   False
#
#    Washer / Dryer  Wheelchair Accessible  Wireless Internet  \
# 0           False                  False               True
# 1           False                  False               True
# 2           False                  False               True
# 3           False                  False               True
# 4           False                  False               True
#
#    translation missing: en.hosting_amenity_49  \
# 0                                       False
# 1                                       False
# 2                                        True
# 3                                       False
# 4                                       False
#
#    translation missing: en.hosting_amenity_50        id
# 0                                       False  12147973
# 1                                       False   3075044
# 2                                        True      6976
# 3                                       False   1436513
# 4                                       False   7651065
#
# [5 rows x 47 columns]

# %%
#Remove first column from listings_amenities whose name is ""
listings_amenities=listings_amenities.drop("",axis=1)
listings_amenities.head()
# Out:
#    24-Hour Check-in  Air Conditioning  Breakfast  Buzzer/Wireless Intercom  \
# 0             False             False      False                     False
# 1             False              True      False                     False
# 2             False              True      False                     False
# 3             False              True       True                     False
# 4             False              True       True                     False
#
#    Cable TV  Carbon Monoxide Detector  Cat(s)  Dog(s)  Doorman  Dryer  ...  \
# 0     False                     False   False    True    False   True  ...
# 1     False                      True   False    True    False   True  ...
# 2      True                      True   False   False    False   True  ...
# 3     False                      True   False   False    False   True  ...
# 4     False                      True   False   False    False   True  ...
#
#    Smoking Allowed  Suitable for Events     TV  Washer  Washer / Dryer  \
# 0            False                False   True    True           False
# 1            False                False   True    True           False
# 2            False                False   True    True           False
# 3            False                False   True    True           False
# 4            False                False  False   False           False
#
#    Wheelchair Accessible  Wireless Internet  \
# 0                  False               True
# 1                  False               True
# 2                  False               True
# 3                  False               True
# 4                  False               True
#
#    translation missing: en.hosting_amenity_49  \
# 0                                       False
# 1                                       False
# 2                                        True
# 3                                       False
# 4                                       False
#
#    translation missing: en.hosting_amenity_50        id
# 0                                       False  12147973
# 1                                       False   3075044
# 2                                        True      6976
# 3                                       False   1436513
# 4                                       False   7651065
#
# [5 rows x 46 columns]

# %%
listings_amenities.columns
# Out:
# Index(['24-Hour Check-in', 'Air Conditioning', 'Breakfast',
#        'Buzzer/Wireless Intercom', 'Cable TV', 'Carbon Monoxide Detector',
#        'Cat(s)', 'Dog(s)', 'Doorman', 'Dryer', 'Elevator in Building',
#        'Essentials', 'Family/Kid Friendly', 'Fire Extinguisher',
#        'First Aid Kit', 'Free Parking on Premises', 'Free Parking on Street',
#        'Gym', 'Hair Dryer', 'Hangers', 'Heating', 'Hot Tub',
#        'Indoor Fireplace', 'Internet', 'Iron', 'Kitchen',
#        'Laptop Friendly Workspace', 'Lock on Bedroom Door', 'Other pet(s)',
#        'Paid Parking Off Premises', 'Pets Allowed',
#        'Pets live on this property', 'Pool', 'Safety Card', 'Shampoo',
#        'Smoke Detector', 'Smoking Allowed', 'Suitable for Events', 'TV',
#        'Washer', 'Washer / Dryer', 'Wheelchair Accessible',
#        'Wireless Internet', 'translation missing: en.hosting_amenity_49',
#        'translation missing: en.hosting_amenity_50', 'id'],
#       dtype='object')

# %% [markdown]
# ## Creating dictionary to caractorizing amenities into meningful groups

# %%
#amenities that cannot be grouped are not taken into consideration
amenity_recode={
                'Air Conditioning':'Weather Control',
                'Indoor Fireplace':'Weather Control',
                'Heating':'Weather Control',
        
                'Carbon Monoxide Detector':'Safety Features',
                'Fire Extinguisher':'Safety Features',
                'First Aid Kit':'Safety Features',
                'Smoke Detector':'Safety Features',
                
                'Buzzer/Wireless Intercom':'Security Features',
                'Doorman':'Security Features',
                'Safety Card':'Security Features',
                'Lock on Bedroom Door':'Security Features',
                
                'Cat(s)':'Pet Friendly',
                'Dog(s)':'Pet Friendly',
                'Pets Allowed':'Pet Friendly',
                'Pets live on this property':'Pet Friendly',
                'Other pet(s)':'Pet Friendly',
                
                'Elevator in Building':'Access Friendly',
                'Wheelchair Accessible':'Access Friendly',
                
                'Essentials':'Essentials',
                'Hair Dryer':'Essentials',
                'Hangers':'Essentials',
                'Iron':'Essentials',
                'Shampoo':'Essentials',             
                
                'Cable TV':'TV',
                'TV':'TV',
                
                'Internet':'Internet',
                'Wireless Internet':'Internet',
                'Laptop Friendly Workspace':'Internet',
                
                'Dryer':'Laundry Facility',
                'Washer':'Laundry Facility',
                'Washer / Dryer':'Laundry Facility',
}

# %%
#Melt the amenities dataframe and recode from the dictionary
listings_amenities_melt = listings_amenities.melt(id_vars=['id'], var_name='amenity')

#Recoding and putting in new column called amenity_modified
listings_amenities_melt = listings_amenities_melt.assign(
    amenity_modified = listings_amenities_melt.amenity.replace(amenity_recode)
)

listings_amenities_melt.head()
# Out:
#          id           amenity  value  amenity_modified
# 0  12147973  24-Hour Check-in  False  24-Hour Check-in
# 1   3075044  24-Hour Check-in  False  24-Hour Check-in
# 2      6976  24-Hour Check-in  False  24-Hour Check-in
# 3   1436513  24-Hour Check-in  False  24-Hour Check-in
# 4   7651065  24-Hour Check-in  False  24-Hour Check-in

# %%
#Melt the amenities dataframe and recode from the dictionary
listings_amenities_melt = listings_amenities.melt(id_vars=['id'], var_name='amenity')

#Recoding and putting in new column called amenity_modified
listings_amenities_melt = listings_amenities_melt.assign(
    amenity_modified = listings_amenities_melt.amenity.replace(amenity_recode)
)

listings_amenities_melt.head()
# Out:
#          id           amenity  value  amenity_modified
# 0  12147973  24-Hour Check-in  False  24-Hour Check-in
# 1   3075044  24-Hour Check-in  False  24-Hour Check-in
# 2      6976  24-Hour Check-in  False  24-Hour Check-in
# 3   1436513  24-Hour Check-in  False  24-Hour Check-in
# 4   7651065  24-Hour Check-in  False  24-Hour Check-in

# %%
#Pivot the melted dataframe before merging with original dataframe
listings_amenities_pivot = listings_amenities_melt.pivot_table(
    index='id',
    columns='amenity_modified',
    values='value', 
    aggfunc='max'
)

listings_amenities_pivot.head()
# Out:
# amenity_modified  24-Hour Check-in  Access Friendly  Breakfast  Essentials  \
# id
# 3353                         False            False      False       False
# 5506                         False            False      False       False
# 6695                          True            False      False        True
# 6976                         False            False      False        True
# 8792                         False             True      False       False
#
# amenity_modified  Family/Kid Friendly  Free Parking on Premises  \
# id
# 3353                            False                     False
# 5506                            False                     False
# 6695                            False                     False
# 6976                            False                      True
# 8792                            False                     False
#
# amenity_modified  Free Parking on Street    Gym  Hot Tub  Internet  ...  \
# id                                                                  ...
# 3353                               False  False    False      True  ...
# 5506                               False  False    False      True  ...
# 6695                               False  False    False      True  ...
# 6976                               False  False    False      True  ...
# 8792                               False  False    False      True  ...
#
# amenity_modified  Pet Friendly   Pool  Safety Features  Security Features  \
# id
# 3353                     False  False             True               True
# 5506                     False  False            False              False
# 6695                     False  False             True              False
# 6976                     False  False             True               True
# 8792                     False  False            False               True
#
# amenity_modified  Smoking Allowed  Suitable for Events     TV  \
# id
# 3353                        False                False  False
# 5506                        False                False   True
# 6695                        False                False   True
# 6976                        False                False   True
# 8792                        False                False   True
#
# amenity_modified  Weather Control  translation missing: en.hosting_amenity_49  \
# id
# 3353                         True                                        True
# 5506                         True                                       False
# 6695                         True                                       False
# 6976                         True                                        True
# 8792                         True                                       False
#
# amenity_modified  translation missing: en.hosting_amenity_50
# id
# 3353                                                    True
# 5506                                                   False
# 6695                                                   False
# 6976                                                    True
# 8792                                                   False
#
# [5 rows x 23 columns]

# %%
#Join the amenities dataframe back to the original listings dataframe
listings_joined=listings.join(listings_amenities_pivot,on="id",how="inner")
listings_joined.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... Pet Friendly   Pool  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...         True  False
# 1  The room is in Roslindale, a diverse and prima...  ...         True  False
# 2  The LOCATION: Roslindale is a safe and diverse...  ...        False  False
# 3  Roslindale is a lovely little neighborhood loc...  ...        False  False
# 4  I love the proximity to downtown, the neighbor...  ...        False  False
#
#   Safety Features Security Features Smoking Allowed Suitable for Events  \
# 0            True             False           False               False
# 1            True              True           False               False
# 2            True              True           False               False
# 3            True              True           False               False
# 4            True             False           False               False
#
#       TV Weather Control translation missing: en.hosting_amenity_49  \
# 0   True            True                                      False
# 1   True            True                                      False
# 2   True            True                                       True
# 3   True            True                                      False
# 4  False            True                                      False
#
#    translation missing: en.hosting_amenity_50
# 0                                       False
# 1                                       False
# 2                                        True
# 3                                       False
# 4                                       False
#
# [5 rows x 133 columns]

# %%
# Generating viridis heatmap to check the correlation among the amenities
listings_selected_amenities=listings_joined[['24-Hour Check-in', 'Access Friendly', 'Breakfast', 'Essentials',
       'Family/Kid Friendly', 'Free Parking on Premises', 'Gym', 'Hot Tub',
       'Internet', 'Kitchen', 'Laundry Facility', 'Pet Friendly', 'Pool',
       'Safety Features', 'Security Features', 'Smoking Allowed',
       'Suitable for Events', 'TV', 'Weather Control']]
fig = plt.figure(figsize= (12,12))
sns.heatmap(listings_selected_amenities.corr(), annot=False, vmax=1, cmap='viridis', square=False)

# %% [markdown]
# From the above heatmap we can say that no 2 amenities have high correlation among them.

# %% [markdown]
# ### Detecting the pick season in boston

# %%
calendar['month'] = pd.DatetimeIndex(calendar['date']).month

# %%
calendar['year'] = pd.DatetimeIndex(calendar['date']).year

# %%
#removing tthe $ sign and converting it into float 
calendar['price'] = calendar['price'].replace('[\$,]','', regex = True).astype(float)

# %%
calendar.groupby(['year','month'])[['price']].mean().plot(kind="bar", color=[ 'lightcoral']);

# %% [markdown]
# ### OBSERVATION
#   On the basis of above chart we can say that in boston August to november is the peak season, with September the highest. we can also analyse the the year starts slow as first three month have the lowest avg price

# %%
# Plot top 10 
top10_neigh = listings.groupby(['neighbourhood_cleansed'])[['price']].mean().sort_values(by='price',ascending=False).head()
top10_neigh.plot(kind='bar', color ='teal');

# %%
#plotting bottom 10 
bottom10_neigh = listings.groupby(['neighbourhood_cleansed'])[['price']].mean().sort_values(by='price',ascending=False).tail()
bottom10_neigh.plot(kind='bar', color = 'pink');

# %% [markdown]
# ### OBSERVATION
# Based on the above analysis we can say that there is fluctuation in price on neighbourhoods.
# South boston waterfront seems to be the most expensive, Mattapan seems to be the cheapest

# %% [markdown]
# ## What are the best places for properties related investments in boston city?

# %%
# analysing the data from the room_type

room_type_price = listings.groupby('room_type').price.mean()
room_type_price
# Out:
# room_type
# Entire home/apt    227.436765
# Private room        96.041364
# Shared room         92.762500
# Name: price, dtype: float64

# %%
#visualising the relation between roomtype and price
room_type_price.plot(kind='bar', color ='green')
plt.ylabel('Avg Price')
plt.xlabel('Room type')
# Out:
# Text(0.5, 0, 'Room type')

# %%
#neighbourhood data analysis of with average price and neighbourhood
per_neighbourhood_price = listings.groupby('neighbourhood_cleansed').price.mean()

# %%
per_neighbourhood_price
# Out:
# neighbourhood_cleansed
# Allston                    112.307692
# Back Bay                   240.950331
# Bay Village                266.833333
# Beacon Hill                224.443299
# Brighton                   118.767568
# Charlestown                198.045045
# Chinatown                  232.352113
# Dorchester                  91.639405
# Downtown                   236.459302
# East Boston                119.153333
# Fenway                     220.393103
# Hyde Park                   86.548387
# Jamaica Plain              138.478134
# Leather District           253.600000
# Longwood Medical Area      138.444444
# Mattapan                    75.125000
# Mission Hill               121.967742
# North End                  195.678322
# Roslindale                  98.428571
# Roxbury                    146.333333
# South Boston               187.609195
# South Boston Waterfront    306.060241
# South End                  204.349693
# West End                   209.591837
# West Roxbury               107.108696
# Name: price, dtype: float64

# %%
per_neighbourhood_price.plot(kind='bar', color='green')

# %%
#lsiting with respect to street
per_street_price = listings.groupby('street').price.mean()
per_street_price
# Out:
# street
# , MA 02467, United States                                            71.500000
# 13th St, Charlestown, MA 02129, United States                       225.000000
# 13th Street, Boston, MA 02129, United States                        204.000000
# 1st Avenue, Boston, MA 02129, United States                         214.500000
# 1st Avenue, Charlestown, MA 02129, United States                    150.000000
# 8th Street, Charlestown, MA 02129, United States                   1000.000000
# A Garden St, Boston, MA 02114, United States                        229.000000
# A Mount Auburn Street, Cambridge, MA 02138, United States            85.000000
# A St, Boston, MA 02210, United States                               170.000000
# A Street, Boston, MA 02210, United States                           315.875000
# Aberdeen Street, Boston, MA 02215, United States                     98.333333
# Academy Hill Rd, Brighton, MA 02135, United States                   70.000000
# Adair Road, Boston, MA 02135, United States                          55.000000
# Adams Street, Boston, MA 02122, United States                        70.000000
# Adams Street, Boston, MA 02124, United States                       175.000000
# Adams Terrace, Boston, MA 02122, United States                      150.000000
# Adamson Street, Boston, MA 02134, United States                     120.000000
# Agassiz Park, Boston, MA 02130, United States                       117.000000
# Ainsley Street, Boston, MA 02122, United States                     120.000000
# Alameda Rd, Boston, MA 02132, United States                         125.000000
# Alaric Street, Boston, MA 02132, United States                       60.000000
# Albany Street, Boston, MA 02118, United States                      138.333333
# Albany Street, Boston, MA 02119, United States                       60.000000
# Albemarle Street, Boston, MA 02115, United States                   109.000000
# Aldworth St, Boston, MA 02130, United States                        200.000000
# Allandale Street, Boston, MA 02130, United States                   349.000000
# Alleghany Street, Boston, MA 02120, United States                    70.500000
# Alleyne Street, Boston, MA 02132, United States                     100.000000
# Allston Street, Boston, MA 02134, United States                      87.666667
# Allston Street, Cambridge, MA 02139, United States                  140.000000
#                                                                       ...
# Winter Street, Boston, MA 02108, United States                      237.666667
# Winter Street, Boston, MA 02122, United States                      125.000000
# Winthrop Street, Boston, MA 02129, United States                    125.000000
# Woodbourne Rd, Boston, MA 02130, United States                      159.000000
# Woodbourne Road, Boston, MA 02130, United States                     90.000000
# Woodlawn Street, Boston, MA 02130, United States                     76.333333
# Woodmont Street, Boston, MA 02135, United States                     40.000000
# Woodstock Avenue, Boston, MA 02135, United States                    60.000000
# Worcester Square, Boston, MA 02118, United States                   176.625000
# Worcester Street, Boston, MA 02118, United States                   128.000000
# Worthington Street, Boston, MA 02120, United States                 115.000000
# Worthington Street, Roxbury Crossing, MA 02120, United States        53.333333
# Wyman Street, Boston, MA 02130, United States                        97.000000
# Yarmouth Place, Boston, MA 02116, United States                     120.000000
# Yarmouth Street, Boston, MA 02116, United States                    228.000000
# Zamora Court, Boston, MA 02130, United States                        99.000000
# Zamora Street, Boston, MA 02130, United States                      200.000000
# boylston st., Boston, MA 02215, United States                        99.000000
# crescent ave, Boston, MA 02125, United States                        68.000000
# dorchester ave, Boston, MA 02125, United States                      59.000000
# kneeland st, Boston, MA 02111, United States                        287.000000
# lubec, east Boston , MA 02128, United States                         80.000000
# marlborough st, Boston, MA 02116, United States                     151.000000
# milk street, Boston, Massachusetts, US, MA 02169, United States      25.000000
# murdock, Brighton, MA 02135, United States                           85.000000
# poplar st, Boston, MA 02131, United States                           58.000000
# sulllivan street, Boston, MA 02129, United States                   165.000000
# vinal street, Boston, MA 02135, United States                        70.000000
# west, Boston, MA 02127, United States                               300.000000
# 波士顿, MA 02115, United States                                        100.000000
# Name: price, Length: 1239, dtype: float64

# %%
plt.figure(figsize=(10,5));
per_street_price[:10].plot(kind='bar', color = 'green');

# %% [markdown]
# ### OBSERVATION
# 1. The average price of home or apartment is more as compare to other types like private rooms or shared rooms. Listing entire home or apartment will definately provide more revenue as compare to indivisual rooms in AirBnb.
# 2. As per the locaton is considered South boston waterfront folowed by back bay have more pricee as compare to other meighbourhoods. Takings first observation into consideration an entire home or apartment particularly i south boston can generate a very hefty revenue more than any other.
#
# 3. Some porch street in boston like Mrtle Street Boston Whraf road have very expensive listing So if you are looking for particular street they can generate a vry high revenue.
